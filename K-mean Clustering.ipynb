# %%
import pandas as pd
import matplotlib.pyplot  as plt

# %%
df = pd.read_csv('500_Person_Gender_Height_Weight_Index.csv')
df  = df.drop('Index', axis=1)

# %%
df
# Out:
#      Gender  Height  Weight
# 0      Male     174      96
# 1      Male     189      87
# 2    Female     185     110
# 3    Female     195     104
# 4      Male     149      61
# ..      ...     ...     ...
# 495  Female     150     153
# 496  Female     184     121
# 497  Female     141     136
# 498    Male     150      95
# 499    Male     173     131
#
# [500 rows x 3 columns]

# %% [markdown]
# ## Scatter Plot

# %%
plt.scatter(df['Height'],df['Weight'])

# %% [markdown]
# # Clustering

# %%
from sklearn.cluster  import KMeans
model = KMeans(n_clusters = 4)
model.fit(df[['Height','Weight']])
# Out:
# KMeans(n_clusters=4)

# %%
model.cluster_centers_
# Out:
# array([[154.24242424,  96.29292929],
#        [167.62420382, 144.28025478],
#        [172.77205882,  65.66911765],
#        [184.14814815, 110.03703704]])

# %%
plt.scatter(df['Height'],df['Weight'])
plt.scatter(model.cluster_centers_[:,0],model.cluster_centers_[:,1])

# %%
model.labels_
# Out:
# array([3, 3, 3, 3, 2, 3, 0, 0, 0, 0, 2, 0, 3, 2, 2, 0, 0, 1, 1, 1, 0, 1,
#        0, 1, 2, 2, 3, 2, 1, 1, 0, 2, 2, 1, 1, 3, 3, 0, 1, 2, 3, 0, 2, 0,
#        3, 2, 3, 3, 2, 1, 1, 2, 0, 3, 3, 3, 0, 3, 2, 0, 2, 1, 2, 2, 1, 1,
#        0, 2, 0, 1, 2, 3, 0, 2, 3, 1, 0, 0, 3, 2, 2, 1, 3, 3, 3, 2, 1, 0,
#        0, 1, 1, 3, 3, 2, 3, 1, 0, 1, 2, 2, 1, 0, 1, 1, 1, 3, 1, 1, 3, 2,
#        2, 1, 1, 3, 3, 2, 2, 0, 0, 1, 0, 3, 1, 1, 1, 0, 3, 0, 1, 2, 1, 2,
#        1, 3, 1, 1, 1, 3, 1, 1, 2, 0, 1, 1, 0, 3, 3, 1, 3, 3, 2, 2, 2, 1,
#        0, 3, 2, 1, 3, 3, 3, 2, 3, 1, 3, 2, 3, 0, 2, 2, 1, 1, 1, 3, 1, 3,
#        3, 3, 1, 3, 2, 3, 0, 2, 3, 2, 1, 2, 1, 0, 0, 0, 0, 1, 0, 0, 2, 3,
#        1, 1, 2, 3, 0, 3, 1, 0, 0, 3, 3, 2, 0, 1, 1, 1, 2, 1, 0, 0, 1, 0,
#        2, 1, 0, 1, 2, 1, 2, 3, 3, 1, 1, 0, 2, 2, 0, 2, 1, 1, 2, 0, 2, 2,
#        2, 1, 2, 0, 3, 1, 3, 0, 2, 1, 1, 1, 1, 2, 3, 0, 1, 1, 0, 1, 1, 2,
#        0, 0, 1, 1, 1, 2, 1, 0, 3, 2, 2, 3, 3, 2, 2, 2, 2, 1, 0, 0, 1, 1,
#        0, 1, 2, 0, 2, 3, 2, 0, 1, 1, 0, 0, 3, 0, 1, 3, 2, 3, 1, 3, 1, 0,
#        2, 1, 1, 1, 1, 2, 2, 1, 3, 1, 0, 1, 3, 3, 0, 1, 2, 2, 3, 0, 2, 3,
#        1, 0, 2, 2, 2, 2, 1, 1, 3, 1, 2, 3, 0, 2, 3, 3, 2, 2, 1, 2, 2, 3,
#        2, 1, 2, 0, 3, 1, 2, 1, 2, 0, 1, 1, 1, 0, 3, 3, 1, 2, 2, 1, 2, 2,
#        3, 1, 0, 1, 0, 2, 0, 2, 3, 1, 1, 2, 1, 0, 2, 2, 2, 2, 2, 3, 1, 2,
#        3, 1, 2, 1, 3, 3, 2, 3, 3, 1, 2, 1, 0, 1, 2, 3, 1, 1, 0, 0, 0, 2,
#        1, 2, 2, 1, 1, 3, 2, 2, 1, 3, 0, 0, 2, 1, 0, 3, 2, 1, 1, 1, 2, 1,
#        3, 2, 1, 1, 3, 1, 2, 3, 0, 1, 1, 0, 3, 2, 2, 2, 3, 2, 0, 1, 3, 1,
#        2, 1, 2, 1, 3, 1, 0, 3, 1, 0, 2, 1, 2, 1, 1, 2, 2, 0, 0, 3, 0, 0,
#        3, 3, 0, 2, 3, 1, 2, 1, 2, 2, 0, 1, 3, 1, 0, 1])

# %%
df['Cluster'] = model.labels_

# %%
df
# Out:
#      Gender  Height  Weight  Cluster
# 0      Male     174      96        3
# 1      Male     189      87        3
# 2    Female     185     110        3
# 3    Female     195     104        3
# 4      Male     149      61        2
# ..      ...     ...     ...      ...
# 495  Female     150     153        1
# 496  Female     184     121        3
# 497  Female     141     136        1
# 498    Male     150      95        0
# 499    Male     173     131        1
#
# [500 rows x 4 columns]

# %%
import seaborn  as sns
sns.scatterplot(data = df  , x = 'Height', y = 'Weight', hue = 'Cluster',palette  =['red', 'green', 'blue', 'pink'])
# Out:
# <AxesSubplot: xlabel='Height', ylabel='Weight'>
